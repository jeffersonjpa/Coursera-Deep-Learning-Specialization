# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffersonjpa/Coursera-Deep-Learning-Specialization/blob/master/Exploratory_Data_Analysis_Studies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Lendo o arquivo CSV

#Lendo todas as colunas do arquivo
df = pd.read_csv('/train.csv', 
                 encoding='ISO-8859-1', 
                 #header=None or header=2 para ler a segunda linha como cabeçalho
                )
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = pd.read_csv('/train.csv', 
                 encoding='ISO-8859-1', usecols=['Pclass', 'Name', 'Ticket'])
df.head()
# Out:
#    Pclass                                               Name            Ticket
# 0       3                            Braund, Mr. Owen Harris         A/5 21171
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...          PC 17599
# 2       3                             Heikkinen, Miss. Laina  STON/O2. 3101282
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)            113803
# 4       3                           Allen, Mr. William Henry            373450

# %%
# Read a comma-separated values (csv) file into DataFrame.
# ?pd.read_csv

# %%
df = pd.read_csv('/train.csv', 
                 encoding='ISO-8859-1', 
#                  na_values=[''] #pode-se adicionar NaN values,
#                 nrows=3 numero de linhas a ser lido do arquiao
                )
# df.head()
df.shape
# Out:
# (891, 12)

# %%
names = df['Name']
# names
type(names)
# Out:
# pandas.core.series.Series

# %%
names_and_tickets = df[['Name', 'Ticket']]
names_and_tickets.head()
type(names_and_tickets)
# Out:
# pandas.core.frame.DataFrame

# %%
df.Ticket
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
# 5                330877
# 6                 17463
# 7                349909
# 8                347742
# 9                237736
# 10              PP 9549
# 11               113783
# 12            A/5. 2151
# 13               347082
# 14               350406
# 15               248706
# 16               382652
# 17               244373
# 18               345763
# 19                 2649
# 20               239865
# 21               248698
# 22               330923
# 23               113788
# 24               349909
# 25               347077
# 26                 2631
# 27                19950
# 28               330959
# 29               349216
#              ...
# 861               28134
# 862               17466
# 863            CA. 2343
# 864              233866
# 865              236852
# 866       SC/PARIS 2149
# 867            PC 17590
# ...

# %%
# df['Relatives'] = df.SibSp +  df.Parch
df['Relatives1Grau'] = df.SibSp +  df.Parch
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  relatives  Relatives  \
# 0      0         A/5 21171   7.2500   NaN        S          1          1
# 1      0          PC 17599  71.2833   C85        C          1          1
# 2      0  STON/O2. 3101282   7.9250   NaN        S          0          0
# ...

# %%
# df.loc[:4, ['Name', 'Ticket', 'Pclass']] #Passando o seguindo parâmetro (nome da coluna como string)

# df.loc[df.Sex == 'male'] Fazendo um filtro ... selecionando somente os homens

df.loc[df.Sex == 'male', ['Name', 'Age']]

# df.iloc[:4, 0:5] #Para passar o número (index) da coluna no segundo parâmetro utilizar o método iloc

# df.iloc[:4, [0,3,5]] #Para passar o número (index) da coluna no segundo parâmetro utilizar o método iloc
# Out:
#                                         Name   Age
# 0                    Braund, Mr. Owen Harris  22.0
# 4                   Allen, Mr. William Henry  35.0
# 5                           Moran, Mr. James   NaN
# 6                    McCarthy, Mr. Timothy J  54.0
# 7             Palsson, Master. Gosta Leonard   2.0
# 12            Saundercock, Mr. William Henry  20.0
# 13               Andersson, Mr. Anders Johan  39.0
# 16                      Rice, Master. Eugene   2.0
# 17              Williams, Mr. Charles Eugene   NaN
# 20                      Fynney, Mr. Joseph J  35.0
# 21                     Beesley, Mr. Lawrence  34.0
# 23              Sloper, Mr. William Thompson  28.0
# 26                   Emir, Mr. Farred Chehab   NaN
# 27            Fortune, Mr. Charles Alexander  19.0
# 29                       Todoroff, Mr. Lalio   NaN
# 30                  Uruchurtu, Don. Manuel E  40.0
# 33                     Wheadon, Mr. Edward H  66.0
# ...
